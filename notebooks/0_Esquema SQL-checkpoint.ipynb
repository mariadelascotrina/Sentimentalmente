# %% [markdown]
# ### Esquema de SQL
#
# -- MySQL Workbench Forward Engineering
#
# SET @OLD_UNIQUE_CHECKS=@@UNIQUE_CHECKS, UNIQUE_CHECKS=0;
# SET @OLD_FOREIGN_KEY_CHECKS=@@FOREIGN_KEY_CHECKS, FOREIGN_KEY_CHECKS=0;
# SET @OLD_SQL_MODE=@@SQL_MODE, SQL_MODE='ONLY_FULL_GROUP_BY,STRICT_TRANS_TABLES,NO_ZERO_IN_DATE,NO_ZERO_DATE,ERROR_FOR_DIVISION_BY_ZERO,NO_ENGINE_SUBSTITUTION';
#
# -- -----------------------------------------------------
# -- Schema mydb
# -- -----------------------------------------------------
# -- -----------------------------------------------------
# -- Schema api
# -- -----------------------------------------------------
#
# -- -----------------------------------------------------
# -- Schema api
# -- -----------------------------------------------------
# CREATE SCHEMA IF NOT EXISTS `api` DEFAULT CHARACTER SET utf8 ;
# USE `api` ;
#
# -- -----------------------------------------------------
# -- Table `api`.`episode`
# -- -----------------------------------------------------
# CREATE TABLE IF NOT EXISTS `api`.`episode` (
#   `episode_id` INT NOT NULL AUTO_INCREMENT,
#   `episode_name` VARCHAR(45) NULL DEFAULT NULL,
#   PRIMARY KEY (`episode_id`),
#   UNIQUE INDEX `episode_id_UNIQUE` (`episode_id` ASC) VISIBLE)
# ENGINE = InnoDB
# DEFAULT CHARACTER SET = utf8mb3;
#
#
# -- -----------------------------------------------------
# -- Table `api`.`person`
# -- -----------------------------------------------------
# CREATE TABLE IF NOT EXISTS `api`.`person` (
#   `person_id` INT NOT NULL AUTO_INCREMENT,
#   `person_name` VARCHAR(45) NULL DEFAULT NULL,
#   PRIMARY KEY (`person_id`))
# ENGINE = InnoDB
# AUTO_INCREMENT = 6
# DEFAULT CHARACTER SET = utf8mb3;
#
#
# -- -----------------------------------------------------
# -- Table `api`.`sentence`
# -- -----------------------------------------------------
# CREATE TABLE IF NOT EXISTS `api`.`sentence` (
#   `sentence_id` INT NOT NULL AUTO_INCREMENT,
#   `sentence` VARCHAR(1000) NULL DEFAULT NULL,
#   `person_id` INT NOT NULL,
#   `episode_episode_id` INT NOT NULL,
#   PRIMARY KEY (`sentence_id`),
#   UNIQUE INDEX `sentence_id_UNIQUE` (`sentence_id` ASC) VISIBLE,
#   INDEX `fk_Sentence_person_idx` (`person_id` ASC) VISIBLE,
#   INDEX `fk_sentence_episode1_idx` (`episode_episode_id` ASC) VISIBLE,
#   CONSTRAINT `fk_sentence_episode1`
#     FOREIGN KEY (`episode_episode_id`)
#     REFERENCES `api`.`episode` (`episode_id`),
#   CONSTRAINT `fk_Sentence_person`
#     FOREIGN KEY (`person_id`)
#     REFERENCES `api`.`person` (`person_id`))
# ENGINE = InnoDB
# DEFAULT CHARACTER SET = utf8mb3;
#
#
# SET SQL_MODE=@OLD_SQL_MODE;
# SET FOREIGN_KEY_CHECKS=@OLD_FOREIGN_KEY_CHECKS;
# SET UNIQUE_CHECKS=@OLD_UNIQUE_CHECKS;
